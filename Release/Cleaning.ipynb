# %% [markdown]
# # Classifying Stocks Using Machine Learning
# ## Cleaning and Analysis
# <hr>
#
# The purpose of this notebook is to evaluate and clean the recently collected data.
#
# ### Objectives
#  - Delete any dates that fall on the weekend
#    - because they may add noise/bias
#  - Review null values ("-1" in dataframe)
#  - Find approach for nulls
#    - nulls in social sentiment should probably be an average because social seems to skew negative
#    - could also try whatever the actual middle would be ("0" for range of -1 to 1 for example)
#  - Shrink and change news sentiment to -1 to 1
#  - Get binary values for beating open and tomorrow's close

# %%
import math
import os
import requests
from datetime import datetime, timedelta
import time
import warnings
import pandas as pd
import numpy as np
from collections import Counter

# %%
# load data
df = pd.read_hdf('stocks.h5')

# %%
# view original dataset
df
# Out:
#     ticker        date                                           headline  \
# 0       FB  2016-08-09  [Onetime Home of Warner Bros.’ Harry Warner As...
# 1       FB  2021-03-15  [Rupert Murdoch's News Corp strikes deal as Fa...
# 2       FB  2021-03-16  [NetApp reformula a organização de vendas glob...
# 3       FB  2021-03-17  [Facebook Promises More Support For Human Righ...
# 4       FB  2021-03-18  [Take A Sneak Peek At The Weirdly-Shaped New P...
# ..     ...         ...                                                ...
# 521   UBER  2021-07-29  [Replay: Joby Aviation Executive Chairman and ...
# 522   UBER  2021-07-30  [Uber looks beyond ride-hailing as rebound and...
# 523   UBER  2021-07-31  [Why No One Should Invest in Food Delivery Sto...
# 524   UBER  2021-08-01  [Videogames entered the mainstream in the pand...
# 525   UBER  2021-08-02  [Disney, Google and other U.S. companies requi...
#
#      news_sentiment_score                                             source  \
# 0                    3.00                                         [DowJones]
# 1                    2.00  [The Guardian, https://nypost.com, https://www...
# 2                    1.91  [businesswire, benzinga, businesswire, busines...
# 3                    1.89  [https://www.forbes.com, businesswire, busines...
# 4                    1.85  [benzinga, benzinga, benzinga, businesswire, b...
# ..                    ...                                                ...
# 521                  1.90  [Yahoo, Yahoo, Yahoo, Yahoo, Yahoo, Yahoo, Uni...
# 522                  2.06  [Yahoo, Yahoo, DowJones, CNBC, Yahoo, Yahoo, Y...
# 523                  2.00   [Yahoo, MarketWatch, SeekingAlpha, SeekingAlpha]
# 524                  2.08  [Yahoo, Yahoo, MarketWatch, MarketWatch, Marke...
# 525                  1.88  [Yahoo, Yahoo, Yahoo, MarketWatch, Yahoo, Yaho...
#
#                                                    url  amount_of_articles  \
# 0    [https://finnhub.io/api/news?id=7dbe5db9757dda...                   1
# 1    [https://finnhub.io/api/news?id=61c0d589cb8bf9...                  70
# 2    [https://finnhub.io/api/news?id=6479351ac59fa2...                  89
# 3    [https://finnhub.io/api/news?id=ad0559e9f8ae60...                  58
# 4    [https://finnhub.io/api/news?id=e851ef47ee28e6...                  77
# ..                                                 ...                 ...
# 521  [https://finnhub.io/api/news?id=62bfd8bf18171d...                  30
# 522  [https://finnhub.io/api/news?id=e725733cc1743a...                  18
# 523  [https://finnhub.io/api/news?id=1185c1d8cba9af...                   4
# 524  [https://finnhub.io/api/news?id=90034f7a2d7274...                  13
# 525  [https://finnhub.io/api/news?id=4d0fe9d5700b42...                  28
#
#         open   close    volume  social_sentiments  mentions
# 0    125.340  125.06  19620967          -1.000000        -1
# 1    269.080  273.75  16856746           0.066288        45
# 2    276.085  279.28  22437665          -0.339269        85
# 3    275.705  284.01  21315044          -0.589213       135
# 4    279.870  278.62  18754853          -0.361794       534
# ..       ...     ...       ...                ...       ...
# 521   44.120   44.69  51033697          -1.000000        -1
# 522   44.380   43.46  22194938           0.195272        40
# 523   -1.000   -1.00        -1          -1.000000        -1
# 524   44.100   43.49  26579889           0.148094        33
# 525   44.100   43.49  26579889          -0.072947        39
#
# [526 rows x 12 columns]

# %%
# find weekday values of rows
weekdates = []
for i in df["date"]:
    weekdates.append(datetime.strptime(i, "%Y-%m-%d").weekday())

# %%
# apply to dataframe
df["weekdates"] = weekdates

# %%
# remove weekends
df = df[df.weekdates != 5]
df = df[df.weekdates != 6]

# %%
del df["weekdates"]

# %%
# get list of stock tickers
tickers = list(df['ticker'].unique())

# %%
# applies average of the ticker to null vals
for i in tickers:
    stockDF = df[df.ticker == i]
    socAvg = stockDF[stockDF.mentions != -1]['social_sentiments'].mean()
    df.loc[(df['mentions'] == -1) & (df['ticker'] == i),'social_sentiments'] = socAvg

# %%
# change mentions from -1 to 0
df.loc[df['mentions'] == -1,'mentions'] = 0

# %%
# resize range of news score from 1 to 4 to -1 to 1 
inLow = 0
inHigh = 4
outLow = -1
outHigh = 1

def resizeRange(inputNum):
    result = ((inputNum - inLow) / (inHigh - inLow)) * (outHigh - outLow) + outLow
    return result

news_sentiment = []
for i in df["news_sentiment_score"]:
    if math.isnan(i):
        news_sentiment.append(0.0)
    else:
        news_sentiment.append(resizeRange(i))

# %%
# add resized sentiment to dataframe
df['news_sentiment'] = news_sentiment

# %%
# remove days where no stock prices are recorded
df = df[df.open != -1.0]

# %%
# get binary values for beating open and stock doing better tomorrow
openVsClose= []
for i in tickers:
    stockDF = df[df.ticker == i]
    for idx,row in stockDF.iterrows():
        if row['open'] < row['close']:
            openVsClose.append(1)
        else:
            openVsClose.append(0)

# %%
tomorrowBetter = []
for i in tickers:
    stockDF = df[df.ticker == i]
    ind = -1
    for idx,row in stockDF.iterrows():
        ind = ind + 1
        try:
            if row['close'] < stockDF.iloc[ind+1]['close']:
                tomorrowBetter.append(1)
            else:
                tomorrowBetter.append(0)
        except:
            tomorrowBetter.append(-1)

# %%
df['close_better'] = openVsClose
df['tomorrow_better'] = tomorrowBetter

# %%
# the last dates will not have proper "tomorrow_better" data
# so if its small set, manual adjust should be good
# big set would be easier just to drop data

# if large set, just do the following
# df = df[df.date != "LatestDate"]

df = df.reset_index(drop=True)
df.sort_values(by="date").tail()
# Out:
#     ticker        date                                           headline  \
# 99      FB  2021-07-30  [Stocks Are Sturdier Than Big Tech’s Tumble Su...
# 199   ORCL  2021-08-02  [Oracle Is Betting Its Cloud Services Will Con...
# 100     FB  2021-08-02  [My $376k 33 Stock Retirement Portfolio Is Out...
# 298   PYPL  2021-08-02  [Bronstein, Gewirtz & Grossman, LLC Notifies S...
# 398   UBER  2021-08-02  [Disney, Google and other U.S. companies requi...
#
#      news_sentiment_score                                             source  \
# 99                   1.87  [MarketWatch, Yahoo, CNBC, Yahoo, MarketWatch,...
# 199                  2.00                  [Yahoo, SeekingAlpha, Thefly.com]
# 100                  1.99  [SeekingAlpha, Yahoo, DowJones, DowJones, Yaho...
# 298                  1.97  [Yahoo, CNBC, Yahoo, Yahoo, Yahoo, Yahoo, Yaho...
# 398                  1.88  [Yahoo, Yahoo, Yahoo, MarketWatch, Yahoo, Yaho...
#
#                                                    url  amount_of_articles  \
# 99   [https://finnhub.io/api/news?id=cc2d5aa5b45bc9...                  43
# 199  [https://finnhub.io/api/news?id=49487e9d83bd41...                   3
# 100  [https://finnhub.io/api/news?id=741f2114bf7596...                  44
# 298  [https://finnhub.io/api/news?id=d237362241a537...                  34
# 398  [https://finnhub.io/api/news?id=4d0fe9d5700b42...                  28
#
#         open   close    volume  social_sentiments  mentions  news_sentiment  \
# 99   354.000  356.30  15976179          -0.490594       113          -0.065
# 199   87.730   87.60   5579320           0.036111         0           0.000
# 100  358.100  351.95  13180439          -0.346166       110          -0.005
# 298  276.885  270.99  10082821          -0.303386        60          -0.015
# 398   44.100   43.49  26579889          -0.072947        39          -0.060
#
#      close_better  tomorrow_better
# 99              1                0
# 199             0               -1
# 100             0               -1
# 298             0               -1
# 398             0               -1

# %%
# looking up the prices to make sure the last values are good
df.tomorrow_better.iloc[[398]] = 0
df.tomorrow_better.iloc[[298]] = 1
df.tomorrow_better.iloc[[100]] = 0
df.tomorrow_better.iloc[[199]] = 1
# Out:
# C:\Users\Ambrose\anaconda3\lib\site-packages\pandas\core\indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
# save the cleaned frame to file
df.to_hdf('stocksCleaned.h5', 'data')
# Out:
# C:\Users\Ambrose\anaconda3\lib\site-packages\pandas\core\generic.py:2490: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block2_values] [items->Index(['ticker', 'date', 'headline', 'source', 'url'], dtype='object')]
#
#   pytables.to_hdf(

# %%
reread = pd.read_hdf('stocksCleaned.h5')

# %%
reread
# Out:
#     ticker        date                                           headline  \
# 0       FB  2016-08-09  [Onetime Home of Warner Bros.’ Harry Warner As...
# 1       FB  2021-03-15  [Rupert Murdoch's News Corp strikes deal as Fa...
# 2       FB  2021-03-16  [NetApp reformula a organização de vendas glob...
# 3       FB  2021-03-17  [Facebook Promises More Support For Human Righ...
# 4       FB  2021-03-18  [Take A Sneak Peek At The Weirdly-Shaped New P...
# ..     ...         ...                                                ...
# 394   UBER  2021-07-27  [WSJ News Exclusive | Ride-Sharing Startup Swv...
# 395   UBER  2021-07-28  [SoftBank Said to Offer $2.1 Billion Uber Stak...
# 396   UBER  2021-07-29  [Replay: Joby Aviation Executive Chairman and ...
# 397   UBER  2021-07-30  [Uber looks beyond ride-hailing as rebound and...
# 398   UBER  2021-08-02  [Disney, Google and other U.S. companies requi...
#
#      news_sentiment_score                                             source  \
# 0                    3.00                                         [DowJones]
# 1                    2.00  [The Guardian, https://nypost.com, https://www...
# 2                    1.91  [businesswire, benzinga, businesswire, busines...
# 3                    1.89  [https://www.forbes.com, businesswire, busines...
# 4                    1.85  [benzinga, benzinga, benzinga, businesswire, b...
# ..                    ...                                                ...
# 394                  1.25  [DowJones, Yahoo, Associated Press, The, GuruF...
# 395                  1.83  [Yahoo, Yahoo, Yahoo, Yahoo, CNBC, CNBC, Yahoo...
# 396                  1.90  [Yahoo, Yahoo, Yahoo, Yahoo, Yahoo, Yahoo, Uni...
# 397                  2.06  [Yahoo, Yahoo, DowJones, CNBC, Yahoo, Yahoo, Y...
# 398                  1.88  [Yahoo, Yahoo, Yahoo, MarketWatch, Yahoo, Yaho...
#
#                                                    url  amount_of_articles  \
# 0    [https://finnhub.io/api/news?id=7dbe5db9757dda...                   1
# 1    [https://finnhub.io/api/news?id=61c0d589cb8bf9...                  70
# 2    [https://finnhub.io/api/news?id=6479351ac59fa2...                  89
# 3    [https://finnhub.io/api/news?id=ad0559e9f8ae60...                  58
# 4    [https://finnhub.io/api/news?id=e851ef47ee28e6...                  77
# ..                                                 ...                 ...
# 394  [https://finnhub.io/api/news?id=1fbbc9dbf5f83e...                   8
# 395  [https://finnhub.io/api/news?id=0592272765241b...                  24
# 396  [https://finnhub.io/api/news?id=62bfd8bf18171d...                  30
# 397  [https://finnhub.io/api/news?id=e725733cc1743a...                  18
# 398  [https://finnhub.io/api/news?id=4d0fe9d5700b42...                  28
#
#         open   close    volume  social_sentiments  mentions  news_sentiment  \
# 0    125.340  125.06  19620967          -0.199921         0           0.500
# 1    269.080  273.75  16856746           0.066288        45           0.000
# 2    276.085  279.28  22437665          -0.339269        85          -0.045
# 3    275.705  284.01  21315044          -0.589213       135          -0.055
# 4    279.870  278.62  18754853          -0.361794       534          -0.075
# ..       ...     ...       ...                ...       ...             ...
# 394   46.540   45.82  16874229           0.000000         1          -0.375
# 395   45.880   46.14  19510262          -0.472390         4          -0.085
# 396   44.120   44.69  51033697          -0.155166         0          -0.050
# 397   44.380   43.46  22194938           0.195272        40           0.030
# 398   44.100   43.49  26579889          -0.072947        39          -0.060
#
#      close_better  tomorrow_better
# 0               0                1
# 1               1                1
# 2               1                1
# 3               1                0
# 4               0                1
# ..            ...              ...
# 394             0                1
# 395             1                0
# 396             1                0
# 397             0                1
# 398             0                0
#
# [399 rows x 15 columns]
